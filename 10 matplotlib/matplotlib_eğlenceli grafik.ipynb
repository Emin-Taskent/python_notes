# %%
import matplotlib.pyplot as plt
import random

# %%
seri=random.sample(range(100,1000),4)
print(seri)
# Out:
# [323, 442, 396, 283]

# %%
plt.xkcd()                  # eğlence metodu :)

x=["2018", "2019", "2020", "2021"]
y=[323, 442, 396, 283]

plt.plot(x,y, color="red", marker="s", mec="orange", mfc="black", label="seri1")
plt.legend() 

plt.show()
